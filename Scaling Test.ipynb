# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
import pandas_profiling as pp
from sklearn import linear_model
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
import pickle

# %% [markdown]
# I pulled the last ten bronze tournaments worth of batting data. This pool of players will serve as the base for the scaling that will take place. Each of the five main batting ratings (babip, gap, power, eye, and strikeouts) will be scaled to the average and standard deviation of this pool of players.

# %%
df = pd.read_csv('pt_bz_batter_scaling.csv', index_col='card_id')
df
# Out:
#                                                 card_title  \
# card_id
# 22991    BUILD-A-LEGEND LF Tim Raines New York Yankees ...
# 21335                     Snapshot LF Alan Wiggins SD 1983
# 21555                     Snapshot LF George Case WSA 1942
# 26163             MLB 2021 Live 2B David Fletcher LAA 2021
# 21297                   Snapshot SS Jose Vizcaino NYM 1995
# ...                                                    ...
# 25919              MLB 2021 Live 1B Jose Martinez NYM 2021
# 26299               MLB 2021 Live SS Amed Rosario CLE 2021
# 21555                     Snapshot LF George Case WSA 1942
# 26163             MLB 2021 Live 2B David Fletcher LAA 2021
# 25934             MLB 2021 Live 2B Luis Guillorme NYM 2021
#
#          batting_ratings_overall_contact  batting_ratings_overall_gap  \
# card_id
# 22991                                146                          160
# 21335                                128                          110
# 21555                                154                          114
# 26163                                132                          138
# 21297                                140                          120
# ...                                  ...                          ...
# 25919                                128                          116
# 26299                                124                          140
# 21555                                154                          114
# 26163                                132                          138
# 25934                                108                          120
#
#          batting_ratings_overall_power  batting_ratings_overall_eye  \
# card_id
# 22991                               67                          138
# 21335                               11                          130
# 21555                               67                           91
# 26163                               45                           91
# 21297                               23                           71
# ...                                ...                          ...
# 25919                              118                          106
# 26299                               93                           43
# 21555                               67                           91
# 26163                               45                           91
# 25934                               37                          124
#
#          batting_ratings_overall_strikeouts  batting_ratings_overall_babip  \
# card_id
# 22991                                   142                            149
# 21335                                   154                            120
# 21555                                   156                            144
# 26163                                   162                            115
# 21297                                   124                            151
# ...                                     ...                            ...
# 25919                                    95                            144
# 26299                                   112                            131
# 21555                                   156                            144
# 26163                                   162                            115
# 25934                                   112                            119
#
#         batting_ratings_overall_hp  batting_ratings_vsr_contact  \
# card_id
# 22991                           \N                          144
# 21335                           \N                          128
# 21555                           \N                          154
# 26163                           \N                          130
# 21297                           \N                          138
# ...                            ...                          ...
# 25919                           \N                          114
# 26299                           \N                          118
# 21555                           \N                          154
# 26163                           \N                          130
# 25934                           \N                          114
#
#          batting_ratings_vsr_gap  ...  batting_ratings_vsr_strikeouts  \
# card_id                           ...
# 22991                        168  ...                             142
# 21335                        112  ...                             156
# 21555                        118  ...                             156
# 26163                        136  ...                             160
# 21297                        126  ...                             124
# ...                          ...  ...                             ...
# 25919                        110  ...                              91
# 26299                        138  ...                             108
# 21555                        118  ...                             156
# 26163                        136  ...                             160
# 25934                        122  ...                             112
#
#          batting_ratings_vsr_babip  batting_ratings_vsl_contact  \
# card_id
# 22991                          146                          148
# 21335                          119                          126
# 21555                          143                          150
# 26163                          114                          138
# 21297                          149                          144
# ...                            ...                          ...
# 25919                          129                          166
# 26299                          127                          142
# 21555                          143                          150
# 26163                          114                          138
# 25934                          126                           95
#
#          batting_ratings_vsl_gap  batting_ratings_vsl_power  \
# card_id
# 22991                        136                         69
# 21335                        104                         11
# 21555                        106                         57
# 26163                        142                         49
# 21297                        102                         23
# ...                          ...                        ...
# 25919                        134                        142
# 26299                        148                         99
# 21555                        106                         57
# 26163                        142                         49
# 25934                        114                         31
#
#          batting_ratings_vsl_eye  batting_ratings_vsl_strikeouts  \
# card_id
# 22991                        134                             146
# 21335                        110                             146
# 21555                         99                             154
# 26163                         93                             166
# 21297                         69                             120
# ...                          ...                             ...
# 25919                        122                             108
# 26299                         47                             122
# 21555                         99                             154
# 26163                         93                             166
# 25934                        110                             108
#
#          batting_ratings_vsl_babip  batting_ratings_misc_bunt  \
# card_id
# 22991                          135                          9
# 21335                          119                        114
# 21555                          136                         27
# 26163                          118                        158
# 21297                          145                         97
# ...                            ...                        ...
# 25919                          177                        124
# 26299                          134                        126
# 21555                          136                         27
# 26163                          118                        158
# 25934                           97                        126
#
#          batting_ratings_misc_bunt_for_hit
# card_id
# 22991                                  116
# 21335                                  176
# 21555                                  166
# 26163                                   87
# 21297                                   99
# ...                                    ...
# 25919                                   65
# 26299                                  104
# 21555                                  166
# 26163                                   87
# 25934                                   63
#
# [4206 rows x 22 columns]

# %% [markdown]
# There's a total of 4,206 players in this set. The most commonly used players are David Fletcher, Pete Rose, and Tim Raines. Jeff Mathis is only seen once in these ten tournaments. Pour one out for the legend.

# %%
df.shape
# Out:
# (4206, 22)

# %%
df['card_title'].value_counts()
# Out:
# MLB 2021 Live 2B David Fletcher LAA 2021              183
# BUILD-A-LEGEND 3B Pete Rose Cincinnati Reds 1978      174
# BUILD-A-LEGEND LF Tim Raines New York Yankees 1997    140
# Snapshot LF George Case WSA 1942                      136
# Snapshot CF Joe Birmingham CLE 1911                   103
#                                                      ...
# MLB 2021 Live C Jeff Mathis ATL 2021                    1
# MLB 2021 Live 1B Travis Shaw MIL 2021                   1
# MLB 2021 Live C Luis Campusano SD 2021                  1
# Snapshot CF Bobby Del Greco KCA 1961                    1
# One Hit Wonder 3B Shane Halter DET 2001                 1
# Name: card_title, Length: 327, dtype: int64

# %% [markdown]
# There's a lot going on in this main cell, but only hav to focus on the first two lines, and the last one (igorning the one that just prints the df for observation).
#
# The first line instantiates our standard scaler that will be used throughout this process.
#
# The second line fits (this is the only really important part) and transforms the five batting ratings to the normal scale, subtracting the mean for the value, and dividing it by the standard deviation of the dataset.
#
# The next couple of lines just creates a data frame, and adds some labels and the index to the data frame.
#
# The last line converts the scaled ratings to the 1-200 scale by multiplying it by 33.667 (the standard deviation used by OOTP in this process) and adding 100 (the mean) back to the value.
#
# The results are then printed out. You can see Jose Vizcaino has average gap power in this pool of players, while Amed Rosario has average home run power.
#
# If I had no interest in observing the data, I would only call the fit method on the standard scaler and skip the rest.

# %%
scaler = StandardScaler()


scaled = scaler.fit_transform(df[['batting_ratings_vsr_babip', 'batting_ratings_vsr_gap',
       'batting_ratings_vsr_power', 'batting_ratings_vsr_eye', 'batting_ratings_vsr_strikeouts']])
scaled = pd.DataFrame(scaled, index=df.index)
scaled.columns = ['batting_ratings_vsr_babip', 'batting_ratings_vsr_gap',
       'batting_ratings_vsr_power', 'batting_ratings_vsr_eye', 'batting_ratings_vsr_strikeouts']
scaled['card_title'] = df.loc[:, 'card_title']

scaled[['batting_ratings_vsr_babip', 'batting_ratings_vsr_gap',
       'batting_ratings_vsr_power', 'batting_ratings_vsr_eye', 'batting_ratings_vsr_strikeouts']] = scaled[['batting_ratings_vsr_babip', 'batting_ratings_vsr_gap',
       'batting_ratings_vsr_power', 'batting_ratings_vsr_eye', 'batting_ratings_vsr_strikeouts']] * 33.667 + 100

scaled
# Out:
#          batting_ratings_vsr_babip  batting_ratings_vsr_gap  \
# card_id
# 22991                   138.492852               169.261851
# 21335                   106.010888                80.310600
# 21555                   134.883745                89.841092
# 26163                    99.995710               118.432565
# 21297                   142.101959               102.548413
# ...                            ...                      ...
# 25919                   118.041245                77.133770
# 26299                   115.635174               121.609395
# 21555                   134.883745                89.841092
# 26163                    99.995710               118.432565
# 25934                   114.432138                96.194752
#
#          batting_ratings_vsr_power  batting_ratings_vsr_eye  \
# card_id
# 22991                    83.782123               148.389441
# 21335                    36.959945               143.896618
# 21555                    87.126565                88.859541
# 26163                    65.387696                93.352364
# 21297                    46.993269                70.888251
# ...                            ...                      ...
# 25919                   119.734868               102.338009
# 26299                   103.848771                39.438492
# 21555                    87.126565                88.859541
# 26163                    65.387696                93.352364
# 25934                    60.371034               134.910973
#
#          batting_ratings_vsr_strikeouts  \
# card_id
# 22991                        110.601876
# 21335                        123.586357
# 21555                        123.586357
# 26163                        127.296209
# 21297                         93.907543
# ...                                 ...
# 25919                         63.301266
# 26299                         79.068136
# 21555                        123.586357
# 26163                        127.296209
# 25934                         82.777988
#
#                                                 card_title
# card_id
# 22991    BUILD-A-LEGEND LF Tim Raines New York Yankees ...
# 21335                     Snapshot LF Alan Wiggins SD 1983
# 21555                     Snapshot LF George Case WSA 1942
# 26163             MLB 2021 Live 2B David Fletcher LAA 2021
# 21297                   Snapshot SS Jose Vizcaino NYM 1995
# ...                                                    ...
# 25919              MLB 2021 Live 1B Jose Martinez NYM 2021
# 26299               MLB 2021 Live SS Amed Rosario CLE 2021
# 21555                     Snapshot LF George Case WSA 1942
# 26163             MLB 2021 Live 2B David Fletcher LAA 2021
# 25934             MLB 2021 Live 2B Luis Guillorme NYM 2021
#
# [4206 rows x 6 columns]

# %% [markdown]
# With the scaling process completed, I pulled all cards from the DB that are eligible for bronze tournaments, ignoring pitchers, along with the ratings used in the model. There's some placeholders here for gb/fb hitter types that aren't included in the database, but the model themselves use. I think these are superfluous but have just thrown them in in the past and haven't gotten rid of them even if they are very very minor.

# %%
roster = pd.read_csv('pt_bz_batter_roster.csv', index_col='card_id')
roster
# Out:
#                                         card_title  batting_ratings_vsr_babip  \
# card_id
# 19836     Unsung Heroes CF Billy Zitzmann CIN 1927                        100
# 19837    Unsung Heroes 3B Eddie Zimmerman BRO 1911                         41
# 19839            Unsung Heroes LF Joe Zdeb KC 1977                        107
# 19846          Unsung Heroes RF Ab Wright CLE 1935                         64
# 19847      Unsung Heroes SS Chuck Wortman CHC 1916                         50
# ...                                            ...                        ...
# 26841        MLB 2021 Live 2B Taylor Walls TB 2021                         94
# 26843     MLB 2021 Live C Sebastian Rivero KC 2021                         57
# 26845    MLB 2021 Live LF Troy Stokes Jr. PIT 2021                         71
# 26846        MLB 2021 Live SS Nick Gordon MIN 2021                        112
# 26851         MLB 2021 Live 3B Connor Joe COL 2021                         99
#
#          batting_ratings_vsr_gap  batting_ratings_vsr_power  \
# card_id
# 19836                        108                         13
# 19837                         79                        118
# 19839                         75                         51
# 19846                        124                         79
# 19847                         67                        126
# ...                          ...                        ...
# 26841                        114                         75
# 26843                         93                         47
# 26845                         99                        114
# 26846                        124                         53
# 26851                        110                        104
#
#          batting_ratings_vsr_eye  batting_ratings_vsr_strikeouts  \
# card_id
# 19836                        102                              99
# 19837                        102                             134
# 19839                         85                             108
# 19846                         81                              85
# 19847                         91                             114
# ...                          ...                             ...
# 26841                        102                              89
# 26843                         49                              71
# 26845                        112                              55
# 26846                         77                              97
# 26851                        126                              81
#
#          running_ratings_speed  batting_ratings_misc_gb_hitter_type_0  \
# card_id
# 19836                      130                                      0
# 19837                      168                                      0
# 19839                      120                                      0
# 19846                       87                                      0
# 19847                      146                                      0
# ...                        ...                                    ...
# 26841                      178                                      0
# 26843                       45                                      0
# 26845                      138                                      0
# 26846                      128                                      0
# 26851                      104                                      0
#
#          batting_ratings_misc_gb_hitter_type_1  \
# card_id
# 19836                                        0
# 19837                                        0
# 19839                                        0
# 19846                                        0
# 19847                                        0
# ...                                        ...
# 26841                                        0
# 26843                                        0
# 26845                                        0
# 26846                                        0
# 26851                                        0
#
#          batting_ratings_misc_gb_hitter_type_2  \
# card_id
# 19836                                        0
# 19837                                        0
# 19839                                        0
# 19846                                        0
# 19847                                        0
# ...                                        ...
# 26841                                        0
# 26843                                        0
# 26845                                        0
# 26846                                        0
# 26851                                        0
#
#          batting_ratings_misc_gb_hitter_type_3  \
# card_id
# 19836                                        0
# 19837                                        0
# 19839                                        0
# 19846                                        0
# 19847                                        0
# ...                                        ...
# 26841                                        0
# 26843                                        0
# 26845                                        0
# 26846                                        0
# 26851                                        0
#
#          batting_ratings_misc_fb_hitter_type_0  \
# card_id
# 19836                                        0
# 19837                                        0
# 19839                                        0
# 19846                                        0
# 19847                                        0
# ...                                        ...
# 26841                                        0
# 26843                                        0
# 26845                                        0
# 26846                                        0
# 26851                                        0
#
#          batting_ratings_misc_fb_hitter_type_1  \
# card_id
# 19836                                        0
# 19837                                        0
# 19839                                        0
# 19846                                        0
# 19847                                        0
# ...                                        ...
# 26841                                        0
# 26843                                        0
# 26845                                        0
# 26846                                        0
# 26851                                        0
#
#          batting_ratings_misc_fb_hitter_type_2  bats_1  bats_2  bats_3
# card_id
# 19836                                        0       1       0       0
# 19837                                        0       1       0       0
# 19839                                        0       1       0       0
# 19846                                        0       1       0       0
# 19847                                        0       1       0       0
# ...                                        ...     ...     ...     ...
# 26841                                        0       0       0       1
# 26843                                        0       1       0       0
# 26845                                        0       1       0       0
# 26846                                        0       0       1       0
# 26851                                        0       1       0       0
#
# [1235 rows x 17 columns]

# %% [markdown]
# This next code block resembles the one from the scaling process before. Instead of calling the fit_transform method, only the transform method is called. This will scale the ratings in this pool to what's actually used.

# %%
rst_scaled = scaler.transform(roster[['batting_ratings_vsr_babip', 'batting_ratings_vsr_gap',
       'batting_ratings_vsr_power', 'batting_ratings_vsr_eye', 'batting_ratings_vsr_strikeouts']])

rst_scaled = pd.DataFrame(rst_scaled, index=roster.index)

rst_scaled.columns = ['batting_ratings_vsr_babip', 'batting_ratings_vsr_gap',
       'batting_ratings_vsr_power', 'batting_ratings_vsr_eye', 'batting_ratings_vsr_strikeouts']

rst_scaled
# Out:
#          batting_ratings_vsr_babip  batting_ratings_vsr_gap  \
# card_id
# 19836                    -0.500395                -0.773549
# 19837                    -2.608664                -2.141774
# 19839                    -0.250261                -2.330495
# 19846                    -1.786796                -0.018666
# 19847                    -2.287064                -2.707936
# ...                            ...                      ...
# 26841                    -0.714795                -0.490467
# 26843                    -2.036930                -1.481251
# 26845                    -1.536663                -1.198170
# 26846                    -0.071594                -0.018666
# 26851                    -0.536128                -0.679188
#
#          batting_ratings_vsr_power  batting_ratings_vsr_eye  \
# card_id
# 19836                    -1.822789                 0.169532
# 19837                     0.784856                 0.169532
# 19839                    -0.879070                -0.397626
# 19846                    -0.183698                -0.531075
# 19847                     0.983534                -0.197453
# ...                            ...                      ...
# 26841                    -0.283037                 0.169532
# 26843                    -0.978409                -1.598666
# 26845                     0.685517                 0.503154
# 26846                    -0.829400                -0.664524
# 26851                     0.437170                 0.970225
#
#          batting_ratings_vsr_strikeouts
# card_id
# 19836                         -0.869666
# 19837                          0.094519
# 19839                         -0.621732
# 19846                         -1.255339
# 19847                         -0.456444
# ...                                 ...
# 26841                         -1.145147
# 26843                         -1.641013
# 26845                         -2.081783
# 26846                         -0.924762
# 26851                         -1.365532
#
# [1235 rows x 5 columns]

# %% [markdown]
# This block just converts the scaled rating back to the 1-200 scale and adds in the card title. Eddie Zimmerman there has an average strikeout rating if he was used in bronze tournaments.

# %%
rst_scaled[['batting_ratings_vsr_babip', 'batting_ratings_vsr_gap',
       'batting_ratings_vsr_power', 'batting_ratings_vsr_eye', 'batting_ratings_vsr_strikeouts']] = rst_scaled[['batting_ratings_vsr_babip', 'batting_ratings_vsr_gap',
       'batting_ratings_vsr_power', 'batting_ratings_vsr_eye', 'batting_ratings_vsr_strikeouts']] * 33.667 + 100

rst_scaled['card_title'] = roster.loc[:, 'card_title']

rst_scaled
# Out:
#          batting_ratings_vsr_babip  batting_ratings_vsr_gap  \
# card_id
# 19836                    83.153210                73.956940
# 19837                    12.174104                27.892899
# 19839                    91.574460                21.539238
# 19846                    39.843925                99.371583
# 19847                    23.001425                 8.831917
# ...                            ...                      ...
# 26841                    75.934996                83.487431
# 26843                    31.422675                50.130712
# 26845                    48.265175                59.661203
# 26846                    97.589638                99.371583
# 26851                    81.950174                77.133770
#
#          batting_ratings_vsr_power  batting_ratings_vsr_eye  \
# card_id
# 19836                    38.632165               105.707626
# 19837                   126.423750               105.707626
# 19839                    70.404358                86.613130
# 19846                    93.815447                82.120307
# 19847                   133.112633                93.352364
# ...                            ...                      ...
# 26841                    90.471006               105.707626
# 26843                    67.059917                46.177726
# 26845                   123.079309               116.939682
# 26846                    72.076579                77.627484
# 26851                   114.718206               132.664562
#
#          batting_ratings_vsr_strikeouts  \
# card_id
# 19836                         70.720970
# 19837                        103.182173
# 19839                         79.068136
# 19846                         57.736488
# 19847                         84.632914
# ...                                 ...
# 26841                         61.446340
# 26843                         44.752007
# 26845                         29.912600
# 26846                         68.866044
# 26851                         54.026637
#
#                                         card_title
# card_id
# 19836     Unsung Heroes CF Billy Zitzmann CIN 1927
# 19837    Unsung Heroes 3B Eddie Zimmerman BRO 1911
# 19839            Unsung Heroes LF Joe Zdeb KC 1977
# 19846          Unsung Heroes RF Ab Wright CLE 1935
# 19847      Unsung Heroes SS Chuck Wortman CHC 1916
# ...                                            ...
# 26841        MLB 2021 Live 2B Taylor Walls TB 2021
# 26843     MLB 2021 Live C Sebastian Rivero KC 2021
# 26845    MLB 2021 Live LF Troy Stokes Jr. PIT 2021
# 26846        MLB 2021 Live SS Nick Gordon MIN 2021
# 26851         MLB 2021 Live 3B Connor Joe COL 2021
#
# [1235 rows x 6 columns]

# %% [markdown]
# Just adding in the other columns that were not scaled. Against, gb/fb hitter types are all zero but the models need them.

# %%
cols = [ 'running_ratings_speed',
       'batting_ratings_misc_gb_hitter_type_0',
       'batting_ratings_misc_gb_hitter_type_1',
       'batting_ratings_misc_gb_hitter_type_2',
       'batting_ratings_misc_gb_hitter_type_3',
       'batting_ratings_misc_fb_hitter_type_0',
       'batting_ratings_misc_fb_hitter_type_1',
       'batting_ratings_misc_fb_hitter_type_2', 'bats_1', 'bats_2', 'bats_3']

for col in cols:
    rst_scaled[col] = roster.loc[:, col]
    
rst_scaled
# Out:
#          batting_ratings_vsr_babip  batting_ratings_vsr_gap  \
# card_id
# 19836                    83.153210                73.956940
# 19837                    12.174104                27.892899
# 19839                    91.574460                21.539238
# 19846                    39.843925                99.371583
# 19847                    23.001425                 8.831917
# ...                            ...                      ...
# 26841                    75.934996                83.487431
# 26843                    31.422675                50.130712
# 26845                    48.265175                59.661203
# 26846                    97.589638                99.371583
# 26851                    81.950174                77.133770
#
#          batting_ratings_vsr_power  batting_ratings_vsr_eye  \
# card_id
# 19836                    38.632165               105.707626
# 19837                   126.423750               105.707626
# 19839                    70.404358                86.613130
# 19846                    93.815447                82.120307
# 19847                   133.112633                93.352364
# ...                            ...                      ...
# 26841                    90.471006               105.707626
# 26843                    67.059917                46.177726
# 26845                   123.079309               116.939682
# 26846                    72.076579                77.627484
# 26851                   114.718206               132.664562
#
#          batting_ratings_vsr_strikeouts  \
# card_id
# 19836                         70.720970
# 19837                        103.182173
# 19839                         79.068136
# 19846                         57.736488
# 19847                         84.632914
# ...                                 ...
# 26841                         61.446340
# 26843                         44.752007
# 26845                         29.912600
# 26846                         68.866044
# 26851                         54.026637
#
#                                         card_title  running_ratings_speed  \
# card_id
# 19836     Unsung Heroes CF Billy Zitzmann CIN 1927                    130
# 19837    Unsung Heroes 3B Eddie Zimmerman BRO 1911                    168
# 19839            Unsung Heroes LF Joe Zdeb KC 1977                    120
# 19846          Unsung Heroes RF Ab Wright CLE 1935                     87
# 19847      Unsung Heroes SS Chuck Wortman CHC 1916                    146
# ...                                            ...                    ...
# 26841        MLB 2021 Live 2B Taylor Walls TB 2021                    178
# 26843     MLB 2021 Live C Sebastian Rivero KC 2021                     45
# 26845    MLB 2021 Live LF Troy Stokes Jr. PIT 2021                    138
# 26846        MLB 2021 Live SS Nick Gordon MIN 2021                    128
# 26851         MLB 2021 Live 3B Connor Joe COL 2021                    104
#
#          batting_ratings_misc_gb_hitter_type_0  \
# card_id
# 19836                                        0
# 19837                                        0
# 19839                                        0
# 19846                                        0
# 19847                                        0
# ...                                        ...
# 26841                                        0
# 26843                                        0
# 26845                                        0
# 26846                                        0
# 26851                                        0
#
#          batting_ratings_misc_gb_hitter_type_1  \
# card_id
# 19836                                        0
# 19837                                        0
# 19839                                        0
# 19846                                        0
# 19847                                        0
# ...                                        ...
# 26841                                        0
# 26843                                        0
# 26845                                        0
# 26846                                        0
# 26851                                        0
#
#          batting_ratings_misc_gb_hitter_type_2  \
# card_id
# 19836                                        0
# 19837                                        0
# 19839                                        0
# 19846                                        0
# 19847                                        0
# ...                                        ...
# 26841                                        0
# 26843                                        0
# 26845                                        0
# 26846                                        0
# 26851                                        0
#
#          batting_ratings_misc_gb_hitter_type_3  \
# card_id
# 19836                                        0
# 19837                                        0
# 19839                                        0
# 19846                                        0
# 19847                                        0
# ...                                        ...
# 26841                                        0
# 26843                                        0
# 26845                                        0
# 26846                                        0
# 26851                                        0
#
#          batting_ratings_misc_fb_hitter_type_0  \
# card_id
# 19836                                        0
# 19837                                        0
# 19839                                        0
# 19846                                        0
# 19847                                        0
# ...                                        ...
# 26841                                        0
# 26843                                        0
# 26845                                        0
# 26846                                        0
# 26851                                        0
#
#          batting_ratings_misc_fb_hitter_type_1  \
# card_id
# 19836                                        0
# 19837                                        0
# 19839                                        0
# 19846                                        0
# 19847                                        0
# ...                                        ...
# 26841                                        0
# 26843                                        0
# 26845                                        0
# 26846                                        0
# 26851                                        0
#
#          batting_ratings_misc_fb_hitter_type_2  bats_1  bats_2  bats_3
# card_id
# 19836                                        0       1       0       0
# 19837                                        0       1       0       0
# 19839                                        0       1       0       0
# 19846                                        0       1       0       0
# 19847                                        0       1       0       0
# ...                                        ...     ...     ...     ...
# 26841                                        0       0       0       1
# 26843                                        0       1       0       0
# 26845                                        0       1       0       0
# 26846                                        0       0       1       0
# 26851                                        0       1       0       0
#
# [1235 rows x 17 columns]

# %% [markdown]
# These next three blocks all go together. I'm just loading the high and low walk rate models built from the base game. High/Low designation is set at 100 based on the rating that has the highest correlation with the stat being modeled. Because I'm lazy, I throw all the variables I'm using at every model and just let Ridge minimize the ones that aren't meaningful.
#
# The results of the walk rate model are shown in that third block.

# %%
directory = 'd:/ootp/batting/models/'
low_bb_file = directory + 'bb_vsr_low_rate'
high_bb_file = directory + 'bb_vsr_high_rate'

low_bb = pickle.load(open(low_bb_file, 'rb'))
high_bb = pickle.load(open(high_bb_file, 'rb'))

variables = ['batting_ratings_vsr_babip', 'batting_ratings_vsr_gap',
       'batting_ratings_vsr_power', 'batting_ratings_vsr_eye',
       'batting_ratings_vsr_strikeouts', 'running_ratings_speed',
       'batting_ratings_misc_gb_hitter_type_0',
       'batting_ratings_misc_gb_hitter_type_1',
       'batting_ratings_misc_gb_hitter_type_2',
       'batting_ratings_misc_gb_hitter_type_3',
       'batting_ratings_misc_fb_hitter_type_0',
       'batting_ratings_misc_fb_hitter_type_1',
       'batting_ratings_misc_fb_hitter_type_2', 'bats_1', 'bats_2', 'bats_3']

# %%
rating = 'batting_ratings_vsr_eye'
rst_scaled['bb_pred'] = 0
rst_scaled.loc[rst_scaled[rating] < 100, 'bb_pred'] = low_bb.predict(rst_scaled.loc[rst_scaled[rating] < 100, variables])
rst_scaled.loc[rst_scaled[rating] >= 100, 'bb_pred'] = high_bb.predict(rst_scaled.loc[rst_scaled[rating] >= 100, variables])

# %%
rst_scaled[['card_title', 'bb_pred']].sort_values(by='bb_pred', ascending=False)
# Out:
#                                       card_title   bb_pred
# card_id
# 22691               Snapshot 1B Lu Blue DET 1926  0.161931
# 22718           Snapshot LF Bob Bescher CIN 1913  0.155175
# 26235    MLB 2021 Live 1B Carlos Santana KC 2021  0.150900
# 26425      MLB 2021 Live CF Aaron Hicks NYY 2021  0.147596
# 20705         Snapshot LF Spike Shannon NYG 1907  0.147148
# ...                                          ...       ...
# 26628    MLB 2021 Live 2B Hanser Alberto KC 2021  0.025413
# 21850             Snapshot RF Mark Quinn KC 2001  0.025173
# 22758           Snapshot C John Bateman HOU 1968  0.023684
# 22091              Snapshot RF Tom Long STL 1916  0.023684
# 20411        Unsung Heroes 2B Red Downs DET 1908  0.018510
#
# [1235 rows x 2 columns]

# %% [markdown]
# Rather than repeat that process for the other five model types, these next couple of code blocks setup the loops to do them automatically.

# %%
rst_scaled.drop('bb_pred',axis=1, inplace=True)

def batting_models():
    directory = "d:/ootp/batting/models/"
    targets = ["bb", "k", "hr", "s", "d", "t"]
    types = ["low", "high"]
    hands = ["vsr", "vsl"]

    models = {}
    for hand in hands:
        models[hand] = {}
        for target in targets:
            for type in types:
                file = directory + "{}_{}_{}_rate".format(target, hand, type)
                model = pickle.load(open(file, "rb"))
                models[hand]["{}_{}".format(target, type)] = model

    return models


models = batting_models()
targets = ["bb", "k", "hr", "s", "d", "t"]
ratings = ["eye", "strikeouts", "power", "babip", "gap", "running_ratings_speed"]

# %%
for hand in models.keys():
    if hand != 'vsl':
        for target in targets:
            rate = target + '_' + hand
            if target != 't':
                rating = 'batting_ratings_{}_{}'.format(hand, ratings[targets.index(target)])
            else:
                rating = 'running_ratings_speed'
            
            rst_scaled.loc[rst_scaled.loc[rst_scaled[rating] < 100].index, rate] = models[
                hand
            ]["{}_low".format(target)].predict(
                rst_scaled.loc[rst_scaled[rating] < 100, variables]
            )

            rst_scaled.loc[rst_scaled.loc[rst_scaled[rating] >= 100].index, rate] = models[
                hand
            ]["{}_high".format(target)].predict(
                rst_scaled.loc[rst_scaled[rating] >= 100, variables]
            )

# %% [markdown]
# This block is just multiplying the percentages by 600 PA. Singles, Doubles, and Triples were modeled on the basis that Three True Outcomes are determined as a pool first, and then BIP events are determined.

# %%
rst_scaled['bb'] = np.round(rst_scaled['bb_vsr'] * 600, 0)
rst_scaled['k'] = np.round(rst_scaled['k_vsr'] * 600, 0)
rst_scaled['hr'] = np.round(rst_scaled['hr_vsr'] * 600, 0)
rst_scaled['tto'] = rst_scaled['bb'] + rst_scaled['k'] + rst_scaled['hr']
rst_scaled['s'] = np.round((600 - rst_scaled['tto']) * rst_scaled['s_vsr'], 0)
rst_scaled['d'] = np.round((600 - rst_scaled['tto']) * rst_scaled['d_vsr'], 0)
rst_scaled['t'] = np.round((600 - rst_scaled['tto']) * rst_scaled['t_vsr'], 0)

rst_scaled['avg'] = (rst_scaled['s'] + 
                     rst_scaled['d'] + 
                     rst_scaled['t'] + 
                     rst_scaled['hr']) / (600 - rst_scaled['bb'])

rst_scaled['obp'] = (rst_scaled['s'] + 
                     rst_scaled['d'] + 
                     rst_scaled['t'] + 
                     rst_scaled['hr'] + 
                     rst_scaled['bb']) / 600

rst_scaled['slg'] = (rst_scaled['s'] + 
                     rst_scaled['d'] * 2 + 
                     rst_scaled['t'] * 3 + 
                     rst_scaled['hr'] * 4) / (600 - rst_scaled['bb'])

rst_scaled['woba'] = (rst_scaled['bb'] * .714 + 
                      rst_scaled['s'] * .918 + 
                      rst_scaled['d'] * 1.314 + 
                      rst_scaled['t'] * 1.669 + 
                      rst_scaled['hr'] * 2.166) / 600

# %% [markdown]
# The woba coefficients used in the last block come from tournament data since the live reset. The top 50 batters vs RHP based on this proces are shown below.

# %%
rst_scaled[['card_title', 'woba']].sort_values(by='woba', ascending=False).head(n=50)
# Out:
#                                                 card_title      woba
# card_id
# 25925              MLB 2021 Live 1B Dominic Smith NYM 2021  0.362222
# 22991    BUILD-A-LEGEND LF Tim Raines New York Yankees ...  0.360583
# 23395    BUILD-A-LEGEND RF Harold Baines Chicago White ...  0.358522
# 22968     BUILD-A-LEGEND 3B Pete Rose Cincinnati Reds 1978  0.354037
# 26191                MLB 2021 Live 2B Luis Arraez MIN 2021  0.353512
# 21555                     Snapshot LF George Case WSA 1942  0.342717
# 24954             One Hit Wonder 1B Chicken Hawks PHI 1925  0.342572
# 25894                  MLB 2021 Live 1B Alec Bohm PHI 2021  0.340232
# 25653                MLB 2021 Live 1B Pavin Smith ARI 2021  0.340093
# 25974            MLB 2021 Live LF Corey Dickerson MIA 2021  0.340043
# 20809                    Snapshot RF Troy O'Leary BOS 1997  0.339432
# 22819                     Snapshot 1B Felipe Alou ATL 1967  0.339423
# 23699                        All-Star CF Gus Bell CIN 1957  0.338072
# 21307                 Snapshot RF Frank Gilhooley NYY 1918  0.336893
# 22689                    Snapshot 1B Bruce Bochte SEA 1981  0.336352
# 20705                   Snapshot LF Spike Shannon NYG 1907  0.336232
# 21082                    Snapshot 1B Frank Isbell CWS 1908  0.335247
# 26227             MLB 2021 Live 2B Whit Merrifield KC 2021  0.334207
# 21063                    Snapshot 3B Lenny Harris LAD 1990  0.333805
# 26307                MLB 2021 Live 1B Josh Naylor CLE 2021  0.333712
# 22299                  Snapshot LF Mickey Hatcher MIN 1984  0.333612
# 23082    BUILD-A-LEGEND LF Hal McRae Kansas City Royals...  0.333272
# 24384             Rookie Sensation 1B Mike Jacobs FLO 2006  0.333092
# 26426              MLB 2021 Live CF Mike Tauchman NYY 2021  0.333035
# 24946                 One Hit Wonder CF Hugh High NYY 1915  0.332995
# 25044               One Hit Wonder LF Harlin Pool CIN 1934  0.332923
# 21467                     Snapshot 2B Denny Doyle BOS 1975  0.332827
# 25591                  MLB 2021 Live LF Tommy Pham SD 2021  0.332543
# 21253                     Snapshot 1B Mark Sweeney SD 2005  0.332242
# 20814                      Snapshot RF Jim Norris CLE 1978  0.331807
# 26038               MLB 2021 Live 1B Yuli Gurriel HOU 2021  0.331753
# 25023               One Hit Wonder 3B Al Gallagher SF 1971  0.331472
# 26061                  MLB 2021 Live 1B Nate Lowe TEX 2021  0.330732
# 26260               MLB 2021 Live RF Nomar Mazara DET 2021  0.330512
# 24443             Rookie Sensation 1B Carl Taylor PIT 1969  0.330212
# 23194    BUILD-A-LEGEND 1B Todd Helton Colorado Rockies...  0.329972
# 26395                  MLB 2021 Live 1B Yandy Diaz TB 2021  0.329972
# 24962                 One Hit Wonder 1B Ham Hyatt STL 1915  0.329573
# 20866                       Snapshot 1B Dan Meyer SEA 1977  0.329315
# 21100                     Snapshot 1B Nippy Jones STL 1949  0.329292
# 22614                    Snapshot 1B Bill Buckner BOS 1985  0.329063
# 26480           MLB 2021 Live 3B Ryan Mountcastle BAL 2021  0.328822
# 21649                     Snapshot RF Joe Wilhoit BSN 1917  0.328462
# 24395              Rookie Sensation RF Ned Harris DET 1942  0.328453
# 20965                   Snapshot CF Ken Landreaux MIN 1979  0.328123
# 21101                    Snapshot LF Jacque Jones MIN 2003  0.328033
# 26608                MLB 2021 Live LF Jake Bauers CLE 2021  0.327993
# 24994               One Hit Wonder CF Albert Hall ATL 1987  0.327198
# 22453                      Snapshot 3B Greg Dobbs MIA 2012  0.327152
# 24907               One Hit Wonder 2B Dutch Meyer CLE 1945  0.327112

# %%
rst_scaled.to_csv('bz_batters_scaled.csv')
